# %%
#eq for a straight line 
#y=mx+b
import numpy as np 
import matplotlib.pyplot as plt

# %%
#beta-> y intercept; omega-> slope(weight)
#1D because x is the only variable input, dimension could be defined as the degree of movements from a point

def linear_func_1D(x,beta,omega):
        y=omega*x+beta
        return y

# %%
x=np.arange(0.0,100.0,0.01)
beta=0.0;omega=1.0 
y=linear_func_1D(x,beta,omega)  #1.

# %%
#plot 1.
fig,ax=plt.subplots()
ax.plot(x,y,'r-')
ax.set_ylim([0,100]); ax.set_xlim([0,100])
ax.set_xlabel('x'); ax.set_ylabel('y')
plt.show()

# %%
#for 2-d, trivially there is x1,x2 and w1,w2 
#little omega(ω) is case specific and big omega(Ω) is genralized 
#dive down ancient greek rabbit hole

# %%
#y=exp[x]=e^x 
#domain [-inf,+inf]
#co-domain= [0,+inf]
#strictly convex in first derivative
'''
https://math.stackexchange.com/questions/1185716/is-exponential-function-strongly-convex#:~:text=The%20exponential%20function%20f(x,f%20is%20a%20convex%20function
https://scipy-lectures.org/advanced/mathematical_optimization/auto_examples/plot_convex.html
'''
# Out:
# '\nhttps://math.stackexchange.com/questions/1185716/is-exponential-function-strongly-convex#:~:text=The%20exponential%20function%20f(x,f%20is%20a%20convex%20function\nhttps://scipy-lectures.org/advanced/mathematical_optimization/auto_examples/plot_convex.html\n'

# %%
#y=log[x]
#domain [0,+inf]
#co-domain [-inf,inf]
#concave (#read more about convex and concave functions)

# %%
'''Supervised_Learning'''
x = np.array([0.03, 0.19, 0.34, 0.46, 0.78, 0.81, 1.08, 1.18, 1.39, 1.60, 1.65, 1.90])
y = np.array([0.67, 0.85, 1.05, 1.0, 1.40, 1.5, 1.3, 1.54, 1.55, 1.68, 1.73, 1.6 ])
print(x)
# Out:
# [0.03 0.19 0.34 0.46 0.78 0.81 1.08 1.18 1.39 1.6  1.65 1.9 ]

# %%
#1d linear regression model
def f(x,phi0,phi1):
    y=phi0+(phi1*x)
    return y

# %%
def plot(x,y,phi0,phi1):
    fig,ax=plt.subplots()
    ax.scatter(x,y)
    plt.xlim([0,2.0])
    plt.ylim([0,2.0])
    ax.set_xlabel('Input, x')
    ax.set_ylabel('Output, y')
    x_line=np.arange(0,2,0.01)
    y_line=f(x_line,phi0,phi1)
    plt.plot(x_line,y_line,'g-',lw=2)

# %%
#plot 2. 
phi0=0.2; phi1=0.4
plot(x,y,phi0,phi1)
